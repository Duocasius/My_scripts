# %% [markdown]
# <a href="https://colab.research.google.com/github/Duocasius/My_scripts/blob/main/Quickstart_jira_rest_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import installed Jira library
from jira import JIRA

#specify a server key/our jira link
jiraOptions = {'server':"https://skaafrica.atlassian.net/"}

# Get a JIRA client instance, pass,
# Authentication parameters
# and the Server name.
jira = JIRA(options = jiraOptions,basic_auth=("deiman@sarao.ac.za","ph9MRTGi3oN2lfanSVCh908B"))

# Search all issues mentioned against a project name.
for singleIssue in jira.search_issues(jql_str = 'project = OPS'):
    print('{}: {}: {}: {}'.format(singleIssue.key, singleIssue.fields.summary, singleIssue.fields.reporter.displayName, singleIssue.fields.status))

# %%
# While fetching details of a single issue,
# pass its UniqueID or Key.
singleIssue = jira.issue('OPS-234')
print('{}: {}: {}'.format(singleIssue.key, singleIssue.fields.summary, singleIssue.fields.reporter.displayName))

# %%
# While fetching details of a single issue,
# pass its UniqueID or Key.
singleIssue = jira.issue('OPS-234')
print('{} \n{} \n{} \n{}: {} \n{}'.format('ID: '+singleIssue.key, 'SUMMARY: '+singleIssue.fields.summary, 'REPORTER: '+singleIssue.fields.reporter.displayName,'STATUS', singleIssue.fields.status, 'DESCRIPTION: '+singleIssue.fields.description))

# %%
# While fetching details of a single issue,
# pass its UniqueID or Key.
singleIssue = jira.issue('OPS-2286')
print('{} \n{} \n{} \n{} \n{}: {} \n{}'.format('ID: '+singleIssue.key, 'SUMMARY: '+singleIssue.fields.summary, 'REPORTER: '+singleIssue.fields.reporter.displayName, 'ASSIGNEE: '+singleIssue.fields.assignee.displayName,'STATUS', singleIssue.fields.status, 'DESCRIPTION: '+singleIssue.fields.description))

# %%
# While fetching details of a single issue,
# pass its UniqueID or Key.
singleIssue = jira.issue('OPS-2286')
print('{} \n{} \n{} \n{} \n{}: {} \n{} \n{} {}'.format('ID: '+singleIssue.key, 'SUMMARY: '+singleIssue.fields.summary, 'REPORTER: '+singleIssue.fields.reporter.displayName, 'ASSIGNEE: '+singleIssue.fields.assignee.displayName,'STATUS', singleIssue.fields.status, 'DESCRIPTION: '+singleIssue.fields.description, 'COMMENTS: ', singleIssue.fields.comment.comments))

# %%
jira_instance = JIRA(options = {'server':"https://skaafrica.atlassian.net/"},basic_auth=("deiman@sarao.ac.za","ph9MRTGi3oN2lfanSVCh908B"))

jira_instance.issue("OPS-27", fields = ["issuetype", "status", "summary"])

# %%
from atlassian import Jira

jira = Jira(
    url='https://skaafrica.atlassian.net/',
    username='deiman@sarao.ac.za',
    password='ph9MRTGi3oN2lfanSVCh908B')
JQL = 'project = OPS AND status IN ("To Do", "In Progress") ORDER BY issuekey'
data = jira.jql(JQL)
print(data)

# %%
from atlassian import Jira
import pandas as pd
jira_instance = Jira(
    url='https://skaafrica.atlassian.net/',
    username='deiman@sarao.ac.za',
    password='ph9MRTGi3oN2lfanSVCh908B'
)
jira_instance.jql("project = OPS", limit = 100, fields=["issuetype", "status", "summary"])

# %%
# Get results of jql query
results = jira_instance.jql("project = OPS", limit = 10, fields=["issuetype", "status", "summary", "reporter", "assignee"])

# %%
# Load the results into a DataFrame. The list of issues is under the "issues" key of the results object.

df = pd.json_normalize(results["issues"])

# %%
# Define which fields we care about using dot notation for nested fields.
FIELDS_OF_INTEREST = ["key", "fields.summary", "fields.issuetype.name", "fields.status.name", "fields.status.statusCategory.name", "fields.reporter.displayName", "fields.assignee.displayName"]

# %%
# Filter to only display the fields we care about. To actually filter them out use df = df[FIELDS_OF_INTEREST].
df[FIELDS_OF_INTEREST]

# %%
def retrieve_all_query_results(jira_instance: Jira, query_string: str) -> list:
    issues_per_query = 100
    list_of_jira_issues = []
    
    # Get the total issues in the results set. This is one extra request but it keeps things simple.
    num_issues_in_query_result_set = jira_instance.jql(query_string, limit = 0)["total"]
    print(f"Query `{query_string}` returns {num_issues_in_query_result_set} issues")
    
        
    # Use floor division + 1 to calculate the number of requests needed
    for query_number in range(0, (num_issues_in_query_result_set // issues_per_query) + 1):
        results = jira_instance.jql(query_string, limit = issues_per_query, start = query_number * issues_per_query)
        list_of_jira_issues.extend(results["issues"])
    
    return list_of_jira_issues

# %%
df = pd.DataFrame.from_records(results["issues"], columns=["key", "fields"])

# %%
df = (
    df["fields"]
    .apply(pd.Series)
    .merge(df, left_index=True, right_index = True)
)

# %%
from atlassian import Jira
from IPython.display import display, HTML, display_html
import pandas as pd
import requests
import json

pd.set_option('max_colwidth', 140)

jira_instance = Jira(
    url='https://skaafrica.atlassian.net/',
    username='deiman@sarao.ac.za',
    password='CY8gtPmvMXRMBNvwzsCH7ABC'
)

# %%
jira_instance.jql("project = OPS", limit = 10, fields=["issuetype", "status", "summary", "reporter", "assignee"])

# %%
# Get results of jql query
results = jira_instance.jql("project = OPS", limit = 100, fields=["issuetype", "status", "summary"])

# Load the results into a DataFrame
df = pd.json_normalize(results["issues"])

# Define which fields we care about using dot notation for nested fields
FIELDS_OF_INTEREST = ["key", "fields.summary", "fields.issuetype.name", "fields.status.name", "fields.status.statusCategory.name"]

# Filter to only display the fields we care about. To actually filter them out use df = df[FIELDS_OF_INTEREST].
df[FIELDS_OF_INTEREST]

# %%
def retrieve_all_query_results(jira_instance: Jira, query_string: str, fields: list) -> list:
    issues_per_query = 100
    list_of_jira_issues = []
    
    # Get the total issues in the results set. This is one extra request but it keeps things simple.
    num_issues_in_query_result_set = jira_instance.jql(query_string, limit = 0)["total"]
    print(f"Query `{query_string}` returns {num_issues_in_query_result_set} issues")
    
    # Use floor division + 1 to calculate the number of requests needed
    for query_number in range(0, (num_issues_in_query_result_set // issues_per_query) + 1):
        results = jira_instance.jql(query_string, limit = issues_per_query, start = query_number * issues_per_query, fields = fields)
        list_of_jira_issues.extend(results["issues"])
    
    return list_of_jira_issues

# %%
jql_result_set_issues = retrieve_all_query_results(jira_instance, "Project in (OPS)", fields = "*all")

# %%
df = pd.json_normalize(jql_result_set_issues)
df[FIELDS_OF_INTEREST]

# %%
import requests
from requests.auth import HTTPBasicAuth
import json
import pandas as pd
  
# URL to Search all issues.
url = "https://skaafrica.atlassian.net/rest/api/2/search"
  
# Create an authentication object,using
# registered emailID, and, token received.
auth = HTTPBasicAuth("deiman@sarao.ac.za","ph9MRTGi3oN2lfanSVCh908B")
  
# The Header parameter, should mention, the
# desired format of data.
headers = {
    "Accept": "application/json"
}
# Mention the JQL query.
# Here, all issues, of a project, are
# fetched,as,no criteria is mentioned.
query = {
    'jql': 'project = OPS '
}
  
# Create a request object with above parameters.
response = requests.get(url, headers=headers, auth=auth, params=query)
  
# Get all project issues,by using the
# json loads method.
projectIssues = json.dumps(json.loads(response.text),
                           sort_keys=True,
                           indent=4,
                           separators=(",", ": "))
  
# The JSON response received, using
# the requests object,
# is an intricate nested object.
# Convert the output to a dictionary object.
dictProjectIssues = json.loads(projectIssues)
  
# We will append,all issues,in a list object.
listAllIssues = []
  
# The Issue details, we are interested in,
# are "Key" , "Summary" and "Reporter Name"
keyIssue, keySummary, keyReporter = "", "", ""
  
  
def iterateDictIssues(oIssues, listInner):
  
    # Now,the details for each Issue, maybe
    # directly accessible, or present further,
    # in nested dictionary objects.
    for key, values in oIssues.items():
  
        # If key is 'fields', get its value,
        # to fetch the 'summary' of issue.
        if(key == "fields"):
  
            # Since type of object is Json str,
            # convert to dictionary object.
            fieldsDict = dict(values)
  
            # The 'summary' field, we want, is 
            # present in, further,nested dictionary
            # object. Hence,recursive call to 
            # function 'iterateDictIssues'.
            iterateDictIssues(fieldsDict, listInner)
  
        # If key is 'reporter',get its value,
        # to fetch the 'reporter name' of issue.
        elif (key == "reporter"):
  
            # Since type of object is Json str 
            # convert to dictionary object.
            reporterDict = dict(values)
  
            # The 'displayName', we want,is present
            # in,further, nested dictionary object.
            # Hence,recursive call to function 'iterateDictIssues'.
            iterateDictIssues(reporterDict, listInner)
  
        # Issue keyID 'key' is directly accessible.
        # Get the value of key "key" and append
        # to temporary list object.
        elif(key == 'key'):
            keyIssue = values
            listInner.append(keyIssue)
  
        # Get the value of key "summary",and,
        # append to temporary list object, once matched.
        elif(key == 'summary'):
            keySummary = values
            listInner.append(keySummary)
  
        # Get the value of key "displayName",and,
        # append to temporary list object,once matched.
        elif(key == "displayName"):
            keyReporter = values
            listInner.append(keyReporter)
  
  
# Iterate through the API output and look
# for key 'issues'.
for key, value in dictProjectIssues.items():
  
    # Issues fetched, are present as list elements,
    # against the key "issues".
    if(key == "issues"):
  
        # Get the total number of issues present
        # for our project.
        totalIssues = len(value)
  
        # Iterate through each issue,and,
        # extract needed details-Key, Summary,
        # Reporter Name.
        for eachIssue in range(totalIssues):
            listInner = []
  
            # Issues related data,is nested 
            # dictionary object.
            iterateDictIssues(value[eachIssue], listInner)
  
            # We append, the temporary list fields,
            # to a final list.
            listAllIssues.append(listInner)
  
# Prepare a dataframe object,with the final 
# list of values fetched.
dfIssues = pd.DataFrame(listAllIssues, columns=["Reporter",
                                                "Summary",
                                                "Key"])
  
# Reframing the columns to get proper 
# sequence in output.
columnTiles = ["Key", "Summary", "Reporter"]
dfIssues = dfIssues.reindex(columns=columnTiles)
print(dfIssues)

# %%
from atlassian import Jira
import pandas as pd
jira_instance = Jira(
    url='https://skaafrica.atlassian.net/',
    username='deiman@sarao.ac.za',
    password='ph9MRTGi3oN2lfanSVCh908B'
)

# Get results of jql query
results = jira_instance.jql("project = OPS", limit = 20, fields=["issuetype", "status", "summary", "reporter", "assignee"])

# Load the results into a DataFrame. The list of issues is under the "issues" key of the results object.
df = pd.json_normalize(results["issues"])

# Define which fields we care about using dot notation for nested fields.
FIELDS_OF_INTEREST = ["key", "fields.summary", "fields.issuetype.name", "fields.status.name", "fields.status.statusCategory.name", "fields.reporter.displayName", "fields.assignee.displayName"]

# Filter to only display the fields we care about. To actually filter them out use df = df[FIELDS_OF_INTEREST].
df[FIELDS_OF_INTEREST]
# Out:
#          key  ... fields.assignee.displayName
# 0   OPS-2286  ...                 Ben Jordaan
# 1   OPS-2285  ...                   Alec Rust
# 2   OPS-2284  ...               Mike Chalmers
# 3   OPS-2283  ...                 CAM Support
# 4   OPS-2282  ...                 Rosly Renil
# 5   OPS-2281  ...                 James Smith
# 6   OPS-2280  ...                 Ben Jordaan
# 7   OPS-2279  ...                 Ben Jordaan
# 8   OPS-2278  ...               Mike Chalmers
# 9   OPS-2277  ...     Mandisa Mandy Jancenkas
# 10  OPS-2276  ...               Mike Chalmers
# 11  OPS-2275  ...                 Ben Jordaan
# 12  OPS-2274  ...               Mike Chalmers
# 13  OPS-2273  ...         Boitumelo Pholoholo
# 14  OPS-2272  ...                 Ben Jordaan
# 15  OPS-2271  ...         Boitumelo Pholoholo
# 16  OPS-2270  ...               Mike Chalmers
# 17  OPS-2269  ...               Benjamin Hugo
# 18  OPS-2268  ...               Mike Chalmers
# 19  OPS-2267  ...                Pieter Kotze
#
# [20 rows x 7 columns]

# %%
#import installed Jira library
from jira import JIRA

#specify a server key/our jira link
jiraOptions = {'server':"https://skaafrica.atlassian.net/"}

# Get a JIRA client instance, pass,
# Authentication parameters
# and the Server name.
jira = JIRA(options = jiraOptions,basic_auth=("deiman@sarao.ac.za","ph9MRTGi3oN2lfanSVCh908B"))

# Search all issues mentioned against a project name.
for singleIssue in jira.search_issues(jql_str = 'project = OPS'):
    print('{} \n{} \n{} \n{} \n{}: {} \n{}\n\n'.format('ID: '+singleIssue.key, 'SUMMARY: '+singleIssue.fields.summary, 'REPORTER: '+singleIssue.fields.reporter.displayName, 'ASSIGNEE: '+singleIssue.fields.assignee.displayName,'STATUS', singleIssue.fields.status, 'DESCRIPTION: '+singleIssue.fields.description,))
# Out:
# ID: OPS-2286
# SUMMARY: M043v fringes on both ends of the spectrum in narrowband
# REPORTER: Duocasius Eiman
# ASSIGNEE: Ben Jordaan
# STATUS: To Do
# DESCRIPTION: Description: mfs53a
# Proposal: SCI-20180516-PS-01
# SB_ID: 20210909-0011
# http://10.97.1.13:8081/tailtask/20210909-0011/progress
#
# During the above-mentioned observation the v-pol of M043 had fringes on the ends of the spectrum in narrowband. These were present on the signal displays on the narrow channel throughout the observation.
#
#
# ID: OPS-2285
# SUMMARY: xhost25 in error
# REPORTER: Duocasius Eiman
# ASSIGNEE: Alec Rust
# STATUS: To Do
# DESCRIPTION: Description: mfs53a
# Proposal: SCI-20180516-PS-01
# SB_ID: 20210909-0011
# [http://10.97.1.13:8081/tailtask/20210909-0011/progress|http://10.97.1.13:8081/tailtask/20210909-0011/progress]
#
# Xhost25 was in error during the above-mentioned observation, and had missing heaps on the grafana display, but no Skarab appeared to be affected by the xhost issue.
#
#
# ID: OPS-2284
# SUMMARY: M035 Azimuth Motion Error
# REPORTER: Lindokuhle Zakithi Biyase
# ASSIGNEE: Mike Chalmers
# STATUS: Investigation
# DESCRIPTION: During TD-01: Bhairavi-B M035 experience an Azimuth Motion Error. The error was reseted  and the antenna repointed back to the source.
#
#  !Screenshot 2021-10-07 at 19.33.13.png|thumbnail!  !Screenshot 2021-10-07 at 19.33.38.png|thumbnail!
#
#
# ID: OPS-2283
# SUMMARY: Nominal precise time sensors values for wide_tied_array_channelised_voltage_0x are not available
# REPORTER: Lindokuhle Zakithi Biyase
# ASSIGNEE: CAM Support
# STATUS: Investigation
# DESCRIPTION: During MB-03: Meertime RelBin J1748-2021B  the observation failed due to the error picked on the Progress  : RequestSensorError: 'Nominal precise time sensors values for wide_tied_array_channelised_voltage_0x are not available.
# Progress Log :  http://10.97.1.13:8081/tailtask/20211007-0015/progress .
#
#
# ID: OPS-2282
# SUMMARY: Dip in SDP Input Data Rates
# REPORTER: Duocasius Eiman
# ASSIGNEE: Rosly Renil
# STATUS: Done
# DESCRIPTION: Description: ADFS 4
# Proposal: SCI-20210212-MV-01
# SB_ID: 20210405-0012
# [http://10.97.1.13:8081/tailtask/20210405-0012/progress|http://10.97.1.13:8081/tailtask/20210405-0012/progress]
#
# During the above-mentioned observation around 03:15 UTC there appeared to be a dip in SDPs Input Data Rates. The Data rates went back to normal without any intervention from the Operator. The cbf-mon display showed network reorder errors on a few of the antennas at the time but everything went back to normal by itself after a while.
#
#
# ID: OPS-2281
# SUMMARY: Intermittent packet loss from S18
# REPORTER: Lindokuhle Zakithi Biyase
# ASSIGNEE: James Smith
# STATUS: Investigation
# DESCRIPTION: During the delay cal in preparation for the  Matangi-A copy Observation, spectrum dips were observed across multiple antennas. These were found to be associated with intermittent packet losses especially associated with S18.
#
# The data losses persisted across the observation and even after a rebuild early in the AM.
#
# !Screenshot 2021-10-06 at 19.22.07.png|width=200,height=183!
#
#
#
#
# ID: OPS-2280
# SUMMARY: M039 rsc.rxl.rfe1.temperature warm
# REPORTER: Martinus Steyn
# ASSIGNEE: Ben Jordaan
# STATUS: To Do
# DESCRIPTION: M039 L-band receiver warmed up gradually from around 00:42 UTC on Wednesday 06-10-2021.
#
#
# ID: OPS-2279
# SUMMARY: M063 rsc.rxl.rfe1.temperature warming up
# REPORTER: Martinus Steyn
# ASSIGNEE: Ben Jordaan
# STATUS: To Do
# DESCRIPTION: M063 L-band receiver started gradually warming up above 30K from around 02:40 UTC on Wednesday 06-10-2021. Was running observations in UHF-band at the time.
#
#
# ID: OPS-2278
# SUMMARY: M030 ap.azim-amp1-failed
# REPORTER: Martinus Steyn (old)
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: During MPIfR Galactic Plane Survey L-band: Setup 07072021_4 observation, M030 encountered:
#
# ap.azim-amp1-failed
# ap.azim-servo-failed
#
# at around 11:42 UTC on Tuesday 05-10-2021 while trying to move to target with the other antennas. Reset failure successfully and repointed M030 back to target. However, while it was trying to move, it failed again with the same errors at around 11:49 UTC. Reset failures again and repointed M030 back to target successfully, and it behaved since.
#
#
#
# ID: OPS-2277
# SUMMARY: tfr.ptic.keysight.msr2.spec2 in error
# REPORTER: Martinus Steyn
# ASSIGNEE: Mandisa Mandy Jancenkas
# STATUS: Done
# DESCRIPTION: Noticed on Monday 04-10-2021 on the TFR health display that tfr.ptic.keysight.msr2.spec2 sensor was in error. Can't say for sure when exactly the sensor went into error.
#
#
# ID: OPS-2276
# SUMMARY: M035 Azimuth motion error
# REPORTER: Audrey Dikgale
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: During SCI-20210212-LV-01: HCG 16 observation, M035 experienced an azimuth motion error 2021.  It was reset and it continued observing.
#
#  !azimuth motion m035.png|thumbnail!
#
#  !actuals.png|thumbnail!
#
#  !m035.png|thumbnail!
#
#
# ID: OPS-2275
# SUMMARY: M000 L-band RFE1 temperature is unstable
# REPORTER: Audrey Dikgale
# ASSIGNEE: Ben Jordaan
# STATUS: To Do
# DESCRIPTION: M000 L-band receiver temperature is unstable and at times unusable above 35K. This has been happening since Friday.
#
# !m000.png|width=200,height=183!
#
#
#
#
# ID: OPS-2274
# SUMMARY: M020 azim/elev motion error
# REPORTER: Tumelo Mangena
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: Observation : MPIfR Galactic Plane Survey L-band: Setup 07072021_1 repeat
# Date : 2021-10-03 11:15:45
# Progress report : http://10.97.1.13:8081/tailtask/20210930-0014/progress
#
#
# During this observation, at 15:31 this antenna experienced elevation motion error and azimuth motion error. The antenna failed to lock on target, however the error was cleared by reset failure command. Attached is the sensor list and sensor graph of sensor in error.
#
#
#
#
#
# ID: OPS-2273
# SUMMARY: M013 Elevation position consistency interlock error
# REPORTER: Audrey Dikgale
# ASSIGNEE: Boitumelo Pholoholo
# STATUS: Done
# DESCRIPTION: During S-band pointing M013 encouterd this elev postion consistency interlok error - it came with elev amp failure.
#
# !M013.png|width=200,height=183!
#
#
#
#
# ID: OPS-2272
# SUMMARY: M040 RXU Is warm
# REPORTER: Audrey Dikgale
# ASSIGNEE: Ben Jordaan
# STATUS: To Do
# DESCRIPTION: M040 RXU warmed up on Friday the 1st, around 15:45 UTC.
#
#  !M040U.png|thumbnail!
#
#
# ID: OPS-2271
# SUMMARY: M000 elev-servo-failed
# REPORTER: Tumelo Mangena
# ASSIGNEE: Boitumelo Pholoholo
# STATUS: Done
# DESCRIPTION: Observation : Steerable beams testing
# Date : 2021-10-01 13:43:19
#
# During this observation, at 13:57 this antenna experienced elev-servo failed error which could not be cleared by reset failure command. The antenna failed to lock on target. This error can be seen on the sensor list and graph (where I include the mode and lock sensor) attached below.
#
#
#
# ID: OPS-2270
# SUMMARY: M005 ap.azim-motion-error, ap.elev-motion-error
# REPORTER: Martinus Steyn
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: During Vela Supercluster observation 269 < l < 274, 1 < b < 6.2 copy observation, M005 encountered:
#
# ap.azim-motion-error
# ap.elev-motion-error
#
# at around 07:55 UTC on Friday 01-10-2021. Reset errors, put AP in back to STOP mode from SHUTDOWN mode, and put receiver indexer back to L-band position from 'undefined'.
#
#
# ID: OPS-2269
# SUMMARY: Gain increase in (mainly) m063 Vpol UHF
# REPORTER: Benjamin Hugo
# ASSIGNEE: Benjamin Hugo
# STATUS: Investigation
# DESCRIPTION: Not quite sure what to make of this, but there is a noticeable increase in mainly the Vpol gain of m063 towards the end of this week's Laduma (SB20210916-0050), which ran  2021-09-28 22:08:54.563 UTC to 2021-09-29 03:43:55.641 UTC
#
# !image-2021-10-01-09-09-21-877.png|width=200,height=183!
#
#
#
# H is also only only affected to a minor degree here which do not point to a pointing issue.
#
#
# ID: OPS-2268
# SUMMARY: m062 azim motion error
# REPORTER: Moloko Hlakola
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: m062 experienced azimuth motion error during observation at 04:11 UTC (2021-10-01).   The errors were reset and continued with the observation.
#
# http://10.97.1.13:8081/tailtask/20210930-0013/progress
#
#
#
# ID: OPS-2267
# SUMMARY: Large rippling on 54Hpol S-band
# REPORTER: Benjamin Hugo
# ASSIGNEE: Pieter Kotze
# STATUS: To Do
# DESCRIPTION: Not sure if this is known - can't immediately find a ticket for it but there are
# significant ripples on the **Hpol** of 54 visible in the bandpass solutions for
# Corkscrew imaging test (S4 4k). They appear to vary with time though because the
# corrected data on calibrators are structured, so I'm preliminarily classifying this as an LNA issue as
# it is similar to what is seen in L-band LNA cases.
#  !image-2021-09-30-21-50-32-768.png|thumbnail! FYI [~accountid:557058:ddf2aad4-8fbb-4a72-b2d1-667af9b22e28]
#
#
# ID: OPS-2266
# SUMMARY: M061 and M011 elevation runaway interlock error
# REPORTER: Audrey Dikgale
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: Once the wind had subsided, while running delay cal, I noticed that M011 and M061 could not lock on target due to ap failures - elevation runway interlock errors. They were successfully reset and the next delay cal was successful.
#
# http://10.97.1.13:8081/tailtask/20210930-0001/progress
#
#  !m011.png|thumbnail!  !m061.png|thumbnail!
#
#  !runaway.png|thumbnail!
#
#
# ID: OPS-2265
# SUMMARY: M044, M053 and M058 ap.elev-runaway-interlock error
# REPORTER: Audrey Dikgale
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: Hours after antennas had been stowed, I decided to build an array for the next observation. This is because the wind/gust speed had not reached their threshold in more than 30 minutes - so no alarms for wind stow had come in. During the delay cal, the antennas moved to the commanded target, but it would seem M044,M053 and M058 then experienced this runaway interlock error at that point.
#
# After resetting these errors,I then manually stowed the 3 antennas as others were already in stow due to another wind stow alarm.
#
# In [4]: cam.m044.req.ap_reset_failures()
# Out[4]: !ap-reset-failures ok
#
# In [12]: cam.m044.req.mode('STOW')
# Out[12]: !mode ok STOW
#
#  !m053.png|thumbnail!  !m044.png|thumbnail!  !m058.png|thumbnail!
#
#
#
#
#
#
#
# ID: OPS-2264
# SUMMARY: M032 Azimuth servo  amp2 failure
# REPORTER: Audrey Dikgale
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: During the Matangi-A observation, M032 experienced azimuth amp 2 failure around 19:07 UTC. I believe the wind speed was picking up because at around 19:33 the observation was interrupted and antennas stowed due to high winds on site.
# I noticed the error when I tried to run a delay cal much later and the antenna only moved in elevation. I reset the ap failure. Seems to be healthy now.
#
#  !m032.png|thumbnail!
#
#
#
#
#
# ID: OPS-2263
# SUMMARY: M040 RXL seems off with RFE1 temp at 0.
# REPORTER: Audrey Dikgale
# ASSIGNEE: Ben Jordaan
# STATUS: Done
# DESCRIPTION: I went through booking for the week and I do not see M040 booked by the receiver team. So I am guessing then that this is some type of failure. The lna's status is failure - while rfel temp is at 0.
#
#  !M040.png|thumbnail!
#
#  !m040.png|thumbnail!
#
#
#
# ID: OPS-2262
# SUMMARY: Kastore_Flap_Controller_Sync_Status (cammon_katstore_flap_state is error)
# REPORTER: Audrey Dikgale
# ASSIGNEE: Audrey Dikgale
# STATUS: Done
# DESCRIPTION: Around 00:06 UTC <Hyrax> From KAROO_MKAT Alarm: new error alarm - Kastore_Flap_Controller_Sync_Status (cammon_katstore_flap_state is error), the error has not cleared.
#
# At the same time when this error happened notifications about the system being on the network back-up link also popped up. I believe that we are still on the back-up link even now.
#
#  !katstore_flap.png|thumbnail!
#
#
# ID: OPS-2261
# SUMMARY: M058V UHF has lower signal power and seems a bit unstable compared to other signals
# REPORTER: Audrey Dikgale
# ASSIGNEE: Ben Jordaan
# STATUS: Investigation
# DESCRIPTION: During the LADUMA season2  observation, M058V power level seemed to be 3dB lower than other signals, but also a bit unstable as well. There were no sensors in error. By unstable I mean the power seems to be going up and down throughout the observation.
#
#  !58v.png|thumbnail!
#
#  !M058.png|thumbnail!
#
# Not sure why the attenuation levels are in warning
# dig.u-band.rfcu.hpol.attenuation warn 2021-09-29 03:24:24 14
# dig.u-band.rfcu.vpol.attenuation warn 2021-09-29 03:24:15 16
#
#
# ID: OPS-2260
# SUMMARY: M009 L-band elev-enc-failed
# REPORTER: Tumelo Mangena
# ASSIGNEE: Boitumelo Pholoholo
# STATUS: Done
# DESCRIPTION: Observation : MPIfR Galactic Plane Survey
# Date : 2021-09-28 11:40:10 UTC
# Progress report : [http://10.97.1.13:8081/tailtask/20210707-0025/dryrun|http://10.97.1.13:8081/tailtask/20210707-0025/dryrun]
#
# During the above mentioned observation, at 16:20:16 UTC the antenna experienced elevation encoder failed error. This caused the antenna to fail locking on target. The operator managed to reset the error and repointed the antenna to continue with observation. However, the error does not appear on the sensor list, but can be seen on the portal logs:
#
#
#
#  2021-09-28T16:20:16.820Z INFO (server,server.py,log,2641) katcp timestamp: 1632846016.80647 device-log ap.VA-AP-CAM-10.97.1.22:34420 Sensor "elev-enc-failed" affecting the device status changed from "ok" to "fail".
#
#
# ID: OPS-2259
# SUMMARY: m013 ap.elev-position-consistency-interlock
# REPORTER: Moloko Hlakola
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: Hi @mike, please have a look at this issue.  I tried to reset but could not.   m013 experienced ap.elev-position-consistency-interlock during observation at 05:32 (20210929) during observation.
#
#
#
# ID: OPS-2258
# SUMMARY: Noise Diode Requests Failed on several antennas - the lead timestamp was too close
# REPORTER: Audrey Dikgale
# ASSIGNEE: Benjamin Hugo
# STATUS: To Do
# DESCRIPTION: At the end of the WC-01: Corkscrew galaxy observation, Noise diode requests had failed. An error about lead timestamp being too close or in the past.
#
# 2021-09-28 03:35:41.768Z ERROR    Requested noise diode timestamp 2021-09-28 03:35:41.713Z will probably be in the past - please increase lead time
# 2021-09-28 03:35:41.768Z ERROR    Skipped setting these noise diodes: m029,m036,m037,m038,m040,m041,m042,m043,m044,m045,m047,m048,m049,m050,m051,m053,m054,m056,m057,m058,m059,m061,m062,m063
#
# http://10.97.1.13:8081/tailtask/20210910-0009/progress
#
#
# ID: OPS-2257
# SUMMARY: M020 Azimuth motion error
# REPORTER: Audrey Dikgale
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: While running a delay cal, I noticed that M020 was flagged, when checking sensor list I noticed that it had experienced an azimuth motion error. I took screenshot of the actual elevation and azimuth attached below. I reset the error and re-ran the delay cal which was successful. This was in preparation for S0 holography.
#
# http://10.97.1.13:8081/tailtask/20210928-0001/progress
#
#  !M020.png|thumbnail!
#
#  !elev_azim_m020.png|thumbnail!
#
#
# ID: OPS-2256
# SUMMARY: M007 Azimuth range switch failure
# REPORTER: Audrey Dikgale
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: During the S-band Corkscrew galaxy observatiion, M007 failed to lock on target due to azimuth range switch failure. The azimuth was 238 deg, which was the same for all antennas that were on target. The failure was reset, AP mode changed to STOP, and redirected to the exact cordinates of the target. It continued observing successfully throughout the observation.
#
# http://10.97.1.13:8081/tailtask/20210910-0009/progress
#
#  !M007.png|thumbnail!
#
#
# ID: OPS-2255
# SUMMARY: Clipping GSM at high elevations and ripples in the UHF spectrum during holography
# REPORTER: Moloko Hlakola
# ASSIGNEE: Marisa Geyer
# STATUS: Done
# DESCRIPTION: We noticed some ripples in the UHF spectrum for all the antennas during "UHF-band holography --scan-extent 15 --tracktime 5 --cycle-duration 5400 elevation-histogram".  The scanning ants spectrum saturates when scanning some of the sources.
#
# http://10.97.1.13:8081/tailtask/20210927-0004/progress
#
#
#
#
# ID: OPS-2254
# SUMMARY: m033 ap mode error
# REPORTER: Kabelo Montshiwa
# ASSIGNEE: Mike Chalmers
# STATUS: Feedback
# DESCRIPTION: m033 ap mode went into error state during the MeerTIME MSP regular (2021 epoch 17) part 3
#  observation at 22:11 UTC. Resetting the failure using operator commands could not clear the error. There are no other associated errors.
#
# !image-2021-09-27-00-22-42-704.png|width=200,height=183!
#
#
#
#
# ID: OPS-2253
# SUMMARY: M056 Failed during delay cal due to CBF CD/SYNC error
# REPORTER: Evelyn Nkgadima
# ASSIGNEE: Alec Rust
# STATUS: Done
# DESCRIPTION: While running delay cal in c544M4k, 8.00s, uhf, at around 15:00 UTC M056 experienced the Sync error and could not give the delay cal solutions. The operator used this command  "./uhf_resync_reset.sh'' to clear the error and the command directory could not be found.
#
# The antenna was marked faulty  and gains set to zero, before the DDT Observations of RS Ophiuchi UHF began
#
# Progress report for the delay cal: [http://10.97.1.13:8081/tailtask/20210926-0019/progress|http://10.97.1.13:8081/tailtask/20210926-0019/progress]
#
#
# ID: OPS-2252
# SUMMARY: SDP Capture done failure
# REPORTER: Moloko Hlakola
# ASSIGNEE: Moloko Hlakola
# STATUS: Done
# DESCRIPTION: SDP product fail to build because capture done failed at 2021-09-23 00:22 during the previous observation .
# I also noticed some CAM alarms before the end of of observation but I am not they are related to the issue.  It also took some time after the data has dropped on grafana for the script to complete.
#
# http://10.97.1.13:8081/tailtask/20210324-0036/progress
#
#
# 2021-09-23 00:22:11.570Z ERROR    'Capture-done' failed on the following proxies: '['sdp']'. Check the relevant proxy logs.
# 2021-09-23 00:22:11.571Z activity INFO end(mkat_session.py:1784) ----- Script ended  /usr/local/bin/astrokat-observe.py (--fbfuse-config-auth-host thn00.tuse.mkat.karoo.kat.ac.za:5003 --description=Shyama-A --observer=Tirna Deb --proposal-id=SCI-20210212-TD-01 --yaml=/tmp/tmpwsoT3b --config-label=424e962,aa2349d --sb-id-code=20210324-0036 --pb-id-code=)
#
#
#
#
#
#
# ID: OPS-2251
# SUMMARY: [irc] <Hyrax> From KAROO-MKAT Alarm: new error alarm - mcp_Msg_Bus_Output_Rate (mcp_msg_bus_out_bytes_ps value = 0 <= 0.1)
# REPORTER: Evelyn Nkgadima
# ASSIGNEE: Evelyn Nkgadima
# STATUS: Done
# DESCRIPTION: When building in S- Band c857m1k, 1s This error appeared on matter most IRC:
#
# * \[irc] <Hyrax> From KAROO_MKAT Alarm: new error alarm - mcp_Msg_Bus_Output_Rate (mcp_msg_bus_out_bytes_ps value = 0 <= 0.1) at around 07:52 SAST.
#
#
# ID: OPS-2250
# SUMMARY: SDP failed to activate during an S band test due to ingest failing to start.
# REPORTER: Evelyn Nkgadima
# ASSIGNEE: Rosly Renil
# STATUS: Done
# DESCRIPTION: At around 6:30 am SAST while building an S-band test. S-Band, C875M4K, 1s  using 53 antennas with  [~accountid:557058:ddf2aad4-8fbb-4a72-b2d1-667af9b22e28] the Array failed to build due to the SMPC Synch error on the SDP.
#
# The Operator contacted Audrey and she suggested we use Sub 2
# Pieter reduced the number of the Antennas to 26 and built successfully.
#
#
# ID: OPS-2249
# SUMMARY: M033 went into e-stop
# REPORTER: Duocasius Eiman
# ASSIGNEE: Mike Chalmers
# STATUS: Investigation
# DESCRIPTION: Description: HI Intensity observation  RISING epoch 12 offset=40
# Proposal: SCI-20210212-MS-01
# SB_ID: 20210916-0024
# http://10.97.1.13:8081/tailtask/20210917-0013/progress
#
# During the above-mentioned observation, M033 went into e-stop mode around 17:00 UTC while observing. Antenna marked faulty and gains zeroed.
#
#
#
# ID: OPS-2248
# SUMMARY: M039 higher power in h-pol .
# REPORTER: Duocasius Eiman
# ASSIGNEE: Ben Jordaan
# STATUS: To Do
# DESCRIPTION: Description: MGPS-L pulsars epoch 2
# Proposal: SCI-20200703-MK-01
# SB_ID: 20210915-0012
# http://10.97.1.13:8081/tailtask/20210915-0012/progress
#
# From the start (13:30 UTC) of the mentioned observation, M039 had a higher power in hpol on the signal display. The antenna was therefore marked faulty and the gains zeroed. !Screenshot 2021-09-19 at 15.46.46.png|thumbnail!  !Screenshot 2021-09-19 at 15.45.56.png|thumbnail!  !Screenshot 2021-09-19 at 16.04.20.png|thumbnail! .
#
#
# ID: OPS-2247
# SUMMARY: M016 low power on the spectrum after phase up
# REPORTER: Duocasius Eiman
# ASSIGNEE: Sarah Buchner
# STATUS: Done
# DESCRIPTION: Description: MGPS-L pulsars epoch 2
# Proposal: SCI-20200703-MK-01
# SB_ID: 20210915-0012
# Phase Up: http://10.97.1.13:8081/tailtask/20210919-0009/progress
#
# After running the phase up in preparation for the above-mentioned observation around 13:20 UTC, M016 showed a lower power in comparison to the rest of the antennas on the spectrum. The antenna was marked faulty and the gains were zeroed.
#  !Screenshot 2021-09-19 at 15.18.53.png|thumbnail!  !Screenshot 2021-09-19 at 15.19.29.png|thumbnail!
#
#
# ID: OPS-2246
# SUMMARY: a lot of new critical alarms from 11:53 to 12:16 SAST
# REPORTER: Duocasius Eiman
# ASSIGNEE: Duocasius Eiman
# STATUS: Done
# DESCRIPTION: Description: Observations of the Galaxy Cluster RXC J1115.8+0129
# Proposal: SCI-20210212-CR-01
# SB_ID: 20210324-0018
# http://10.97.1.13:8081/tailtask/20210324-0018/progress
#
# During the above-mentioned observation the below-mentioned alarms were displayed:
# 11:53 AM SAST
# [irc] <Hyrax> From KAROO_MKAT Alarm: new warn alarm - Sources_not_uptodate (agg_cam_sources_uptodate is False)
#
# 11:53 AM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new warn alarm - Varkatconfig_not_up_to_date (agg_cam_varkatconfig_uptodate is False)
#
# 11:56 AM
# [irc] <Hyrax> From KAROO_MKAT Alarm: new warn alarm - Varkatconfig_not_up_to_date (agg_cam_varkatconfig_uptodate is False)
#
# 11:56 AM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ANC_Wind_Reporting_Failure (agg_anc_wind_reporting_ok is False)
#
# 11:56 AM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Combo_Comms (anc_asccombo_module_combination_input_comms_ok is False)
#
# 11:56 AM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Analog_Comms (anc_asc_module_analog_input_comms_ok is False)
#
# 11:56 AM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Digital_Comms (anc_asc_module_digital_input_comms_ok is False)
#
# 11:58 AM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ANC_Wind_Reporting_Failure (agg_anc_wind_reporting_ok is False)
#
# 11:58 AM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Combo_Comms (anc_asccombo_module_combination_input_comms_ok is False)
#
# 11:58 AM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Analog_Comms (anc_asc_module_analog_input_comms_ok is False)
#
# 11:58 AM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Digital_Comms (anc_asc_module_digital_input_comms_ok is False)
#
# 11:58 AM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new warn alarm - Sources_not_uptodate (agg_cam_sources_uptodate is False)
#
# 12:00 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ANC_Wind_Reporting_Failure (agg_anc_wind_reporting_ok is False)
#
# 12:00 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Combo_Comms (anc_asccombo_module_combination_input_comms_ok is False)
#
# 12:00 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Analog_Comms (anc_asc_module_analog_input_comms_ok is False)
#
# 12:00 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Digital_Comms (anc_asc_module_digital_input_comms_ok is False)
#
# 12:02 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ANC_Wind_Reporting_Failure (agg_anc_wind_reporting_ok is False)
#
# 12:02 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Combo_Comms (anc_asccombo_module_combination_input_comms_ok is False)
#
# 12:02 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Analog_Comms (anc_asc_module_analog_input_comms_ok is False)
#
# 12:02 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Digital_Comms (anc_asc_module_digital_input_comms_ok is False)
#
# 12:04 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ANC_Wind_Reporting_Failure (agg_anc_wind_reporting_ok is False)
#
# 12:04 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Combo_Comms (anc_asccombo_module_combination_input_comms_ok is False)
#
# 12:04 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Analog_Comms (anc_asc_module_analog_input_comms_ok is False)
#
# 12:04 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Digital_Comms (anc_asc_module_digital_input_comms_ok is False)
#
# 12:04 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new warn alarm - Sources_not_uptodate (agg_cam_sources_uptodate is False)
#
# 12:06 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ANC_Wind_Reporting_Failure (agg_anc_wind_reporting_ok is False)
#
# 12:06 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Combo_Comms (anc_asccombo_module_combination_input_comms_ok is False)
#
# 12:06 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Analog_Comms (anc_asc_module_analog_input_comms_ok is False)
#
# 12:06 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Digital_Comms (anc_asc_module_digital_input_comms_ok is False)
#
# 12:08 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ANC_Wind_Reporting_Failure (agg_anc_wind_reporting_ok is False)
#
# 12:08 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Combo_Comms (anc_asccombo_module_combination_input_comms_ok is False)
#
# 12:08 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Analog_Comms (anc_asc_module_analog_input_comms_ok is False)
#
# 12:08 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Digital_Comms (anc_asc_module_digital_input_comms_ok is False)
#
# 12:08 PM
# [irc] <Hyrax> From KAROO_MKAT Alarm: new warn alarm - Sources_not_uptodate (agg_cam_sources_uptodate is False)
#
# 12:10 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ANC_Wind_Reporting_Failure (agg_anc_wind_reporting_ok is False)
#
# 12:10 PM
# [irc] <Hyrax> From KAROO_MKAT Alarm: new warn alarm - Varkatconfig_not_up_to_date (agg_cam_varkatconfig_uptodate is False)
#
# 12:10 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Combo_Comms (anc_asccombo_module_combination_input_comms_ok is False)
#
# 12:10 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Analog_Comms (anc_asc_module_analog_input_comms_ok is False)
#
# 12:10 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Digital_Comms (anc_asc_module_digital_input_comms_ok is False)
#
# 12:12 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ANC_Wind_Reporting_Failure (agg_anc_wind_reporting_ok is False)
#
# 12:12 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Combo_Comms (anc_asccombo_module_combination_input_comms_ok is False)
#
# 12:12 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Analog_Comms (anc_asc_module_analog_input_comms_ok is False)
#
# 12:12 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Digital_Comms (anc_asc_module_digital_input_comms_ok is False)
#
# 12:14 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ANC_Wind_Reporting_Failure (agg_anc_wind_reporting_ok is False)
#
# 12:14 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Combo_Comms (anc_asccombo_module_combination_input_comms_ok is False)
#
# 12:14 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Digital_Comms (anc_asc_module_digital_input_comms_ok is False)
#
# 12:14 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Analog_Comms (anc_asc_module_analog_input_comms_ok is False)
#
# 12:14 PM
# [irc] <Hyrax> From KAROO_MKAT Alarm: new warn alarm - Sources_not_uptodate (agg_cam_sources_uptodate is False)
#
# 12:16 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ANC_Wind_Reporting_Failure (agg_anc_wind_reporting_ok is False)
#
# 12:16 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Combo_Comms (anc_asccombo_module_combination_input_comms_ok is False)
#
# 12:16 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Analog_Comms (anc_asc_module_analog_input_comms_ok is False)
#
# 12:16 PM
# [irc] <Hyrax> From KAROO_MKAT_RTS Alarm: new critical alarm - ASC_Digital_Comms (anc_asc_module_digital_input_comms_ok is False)
#
# Suleiman Hoosen suggested we restarted the ASC, ASCombo and ANC processes on the RTS system. These processes were restarted at 14:25 SAST after the observation.
#
#
# ID: OPS-2245
# SUMMARY: M005 Undefined indexer position
# REPORTER: Mandy Ndlovu
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: eRO-QPE1 epoch 2 Observation 2021-09-19 04:52-07:08 SAST SB_ID: 20210915-0013
#
# While running the delay calibration script in preparation for the above-mentioned observation, the indexer position for M005 became undefined. The issue occurred at approximately 02:42 UTC. This resulted in the delay solutions for M005 not being found. To clear the error, the OoD set the antenna into stop mode, reset the ap failures and positioned the receiver indexer. The issue caused the observation start time to be delayed by 7 min, there was already not much building time.
#
# [http://10.97.1.13:8081/tailtask/20210919-0002/progress|http://10.97.1.13:8081/tailtask/20210919-0002/progress]
#
#
# ID: OPS-2244
# SUMMARY: M052 is warm in L-band and U-band
# REPORTER: Lavashni Kara
# ASSIGNEE: Ben Jordaan
# STATUS: Feedback
# DESCRIPTION: Observation description: Observations of the Galaxy Cluster Abell 2029
# Progress log: http://10.97.1.13:8081/tailtask/20210324-0010/progress
# Start time: 2021-09-18 09:16 UTC
#
# During the above-mentioned observation in L-band, both L-band and U-band temperatures for M052 increased to a temperature above 290 K. The LNAs were switched off in U-band but the LNAs were still on in L-band even though the temperature was so high.  I marked this antenna as faulty during the observation.
#
#  !image-2021-09-18-15-24-37-058.png|thumbnail!
#
# L-band screenshots:
#
#  !image-2021-09-18-15-07-38-003.png|thumbnail!
#
#  !image-2021-09-18-15-07-49-699.png|thumbnail!
#
#
# U-band screenshots:
#
#  !image-2021-09-18-15-20-31-745.png|thumbnail!
#
#  !image-2021-09-18-15-20-40-310.png|thumbnail!
#
#
#
# ID: OPS-2243
# SUMMARY: comms through leaf2 failed
# REPORTER: Duocasius Eiman
# ASSIGNEE: Alec Rust
# STATUS: Done
# DESCRIPTION: While building from 12:00 UTC comms through leaf2 failed, affecting antennas M016-M031 causing the subarray to fail.
#
# Marc and Alec managed to clear the issue by stopping the digitiser streams and also rebooting the leaf.
# Thereafter we managed to successfully built an array and continue observing.
#
#
# ID: OPS-2242
# SUMMARY: M039 AP Profibus Error
# REPORTER: Lindokuhle Zakithi Biyase
# ASSIGNEE: Priscilla Appies
# STATUS: Done
# DESCRIPTION: At 06:14 M039 reported an AP Profibus Error. I tried resetting the error and it did not clear !Screenshot 2021-09-17 at 08.49.04.png|thumbnail!  !Screenshot 2021-09-17 at 08.49.32.png|thumbnail!
#
#
# ID: OPS-2241
# SUMMARY: M017 noisy delay solutions in L-band
# REPORTER: Duocasius Eiman
# ASSIGNEE: Alec Rust
# STATUS: Done
# DESCRIPTION: Description: HI Intensity observation  RISING epoch 6
# Proposal: SCI-20210212-MS-01
# SB_ID: 20210907-0014
# [http://10.97.1.13:8081/tailtask/20210915-0010/progress|http://10.97.1.13:8081/tailtask/20210915-0010/progress]
#
# In preperation for the above-mentioned observation around 16:16 UTC, M017 showed high delay solutions and were noisy on wtabhh/vv. Antenna marked faulty and gains zeroed.
#
#
# ID: OPS-2240
# SUMMARY: M005 DIG-UHF057 intermittent 1PPS
# REPORTER: Lindokuhle Zakithi Biyase
# ASSIGNEE: Boitumelo Pholoholo
# STATUS: Feedback
# DESCRIPTION: During Henno's  daily Digitiser site tests   intermittent 1PPS issues were picked  up on M005 DIG-UHF057
#
#
# ID: OPS-2239
# SUMMARY: <Hyrax> From KAROO_MKAT Alarm: new error alarm - Kastore_Flap_Controller_Sync_Status (cammon_katstore_flap_state is error)
# REPORTER: Duocasius Eiman
# ASSIGNEE: Duocasius Eiman
# STATUS: Done
# DESCRIPTION: 19:27 UTC
# <Hyrax> From KAROO_MKAT Alarm: new error alarm - Kastore_Flap_Controller_Sync_Status (cammon_katstore_flap_state is error)
#
#
# ID: OPS-2238
# SUMMARY: M013 failed to lock on target
# REPORTER: Duocasius Eiman
# ASSIGNEE: Mike Chalmers
# STATUS: Done
# DESCRIPTION: Description: TRAPUM Fermi Sources: Shallow Survey UHF Pass 1 Block 1
# Proposal: SCI-20180923-MK-02
# SB_ID: 20210415-0008
# http://10.97.1.13:8081/tailtask/20210415-0008/progress
#
# During the above-mentioned observation m013 failed to lock on target, no errors were present at the time. After resetting failures and repointing the antenna, the antenna started tracking again.
#
#
# ID: OPS-2237
# SUMMARY: Anomalous delay calibration reset occurred during S-band observation
# REPORTER: Mattieu de Villiers
# ASSIGNEE: Kim McAlpine
# STATUS: To Do
# DESCRIPTION: During an S4 band holography observation, it seems that a delay calibration reset occurred unexpectedly.  It seems that the original phase slopes prior to delay-calibration mysteriously reappeared after 'Tue Sep 14 10:56:17 2021' UTC, midway through the subsequent holography observation. It is unclear what malfunction occurred. Has anything like this happened in the past?
#
# Look at the trackant-trackant pair m019-m030, as an example, before and after the event which occurred at 'Tue Sep 14 10:56:17 2021' UTC (1631609777.8755698)
#
# {code:python}import katdal
# h5=katdal.open('1631608504_sdp_l0.full.rdb')
# print(time.ctime(h5.timestamps[635]))
# plot(angle(h5.vis[635,:,h5.corr_products.tolist().index(['m019h','m030h'])]))
# plot(angle(h5.vis[636,:,h5.corr_products.tolist().index(['m019h','m030h'])]))
# legend(['m019h-m030h before 1631609777.8755698','m019h-m030h after 1631609777.8755698']){code}
#
# !delaycalreset.png|width=575,height=436!

# %%
#import installed Jira library
from jira import JIRA

#specify a server key/our jira link
jiraOptions = {'server':"https://skaafrica.atlassian.net/"}

# Get a JIRA client instance, pass,
# Authentication parameters
# and the Server name.
jira = JIRA(options = jiraOptions,basic_auth=("deiman@sarao.ac.za","ph9MRTGi3oN2lfanSVCh908B"))

# While fetching details of a single issue,
# pass its UniqueID or Key.
singleIssue = jira.issue('OPS-2286')
print('{} \n{} \n{} \n{} \n{}: {} \n{} \n{} {}'.format('ID: '+singleIssue.key, 'SUMMARY: '+singleIssue.fields.summary, 'REPORTER: '+singleIssue.fields.reporter.displayName, 'ASSIGNEE: '+singleIssue.fields.assignee.displayName,'STATUS', singleIssue.fields.status, 'DESCRIPTION: '+singleIssue.fields.description, 'COMMENTS: ', singleIssue.fields.comment.comments))
# Out:
# ID: OPS-2286
# SUMMARY: M043v fringes on both ends of the spectrum in narrowband
# REPORTER: Duocasius Eiman
# ASSIGNEE: Ben Jordaan
# STATUS: To Do
# DESCRIPTION: Description: mfs53a
# Proposal: SCI-20180516-PS-01
# SB_ID: 20210909-0011
# http://10.97.1.13:8081/tailtask/20210909-0011/progress
#
# During the above-mentioned observation the v-pol of M043 had fringes on the ends of the spectrum in narrowband. These were present on the signal displays on the narrow channel throughout the observation.
# COMMENTS:  [<JIRA Comment: id='152220'>]
